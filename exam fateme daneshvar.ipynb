# %%
# !git clone https://github.com/F-Aghaeipoor/Knee-X-ray.git
# Out:
# Cloning into 'Knee-X-ray'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 10 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), 31.75 MiB | 18.74 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
import os

# مسیر اصلی پروژه
data_path = "/content/Knee-X-ray"

# مشاهده پوشه‌ها
for root, dirs, files in os.walk(data_path):
    print(f"{root} : {len(files)} files")
# Out:
# /content/Knee-X-ray : 4 files
# /content/Knee-X-ray/.git : 5 files
# /content/Knee-X-ray/.git/logs : 1 files
# /content/Knee-X-ray/.git/logs/refs : 0 files
# /content/Knee-X-ray/.git/logs/refs/remotes : 0 files
# /content/Knee-X-ray/.git/logs/refs/remotes/origin : 1 files
# /content/Knee-X-ray/.git/logs/refs/heads : 1 files
# /content/Knee-X-ray/.git/objects : 0 files
# /content/Knee-X-ray/.git/objects/pack : 2 files
# /content/Knee-X-ray/.git/objects/info : 0 files
# /content/Knee-X-ray/.git/refs : 0 files
# /content/Knee-X-ray/.git/refs/remotes : 0 files
# /content/Knee-X-ray/.git/refs/remotes/origin : 1 files
# /content/Knee-X-ray/.git/refs/tags : 0 files
# /content/Knee-X-ray/.git/refs/heads : 1 files
# /content/Knee-X-ray/.git/branches : 0 files
# /content/Knee-X-ray/.git/hooks : 13 files
# /content/Knee-X-ray/.git/info : 1 files

# %%
import os
os.listdir('/content/Knee-X-ray')
# Out:
# ['README.md',
#  'val.rar',
#  'test.rar',
#  'val',
#  'train.rar',
#  'test',
#  '.git',
#  'train']

# %%
# !file /content/Knee-X-ray/train.rare
# Out:
# /content/Knee-X-ray/train.rare: cannot open `/content/Knee-X-ray/train.rare' (No such file or directory)

# %%
import os

for root, dirs, files in os.walk("/content/Knee-X-ray"):
    print(f"{root} -> Files: {files}")
# Out:
# /content/Knee-X-ray -> Files: ['README.md', 'val.rar', 'test.rar', 'train.rar']
# /content/Knee-X-ray/.git -> Files: ['description', 'index', 'config', 'HEAD', 'packed-refs']
# /content/Knee-X-ray/.git/logs -> Files: ['HEAD']
# /content/Knee-X-ray/.git/logs/refs -> Files: []
# /content/Knee-X-ray/.git/logs/refs/remotes -> Files: []
# /content/Knee-X-ray/.git/logs/refs/remotes/origin -> Files: ['HEAD']
# /content/Knee-X-ray/.git/logs/refs/heads -> Files: ['master']
# /content/Knee-X-ray/.git/objects -> Files: []
# /content/Knee-X-ray/.git/objects/pack -> Files: ['pack-0bacd4d97d34431ecfb1316b75b5a79f94c5ec0f.idx', 'pack-0bacd4d97d34431ecfb1316b75b5a79f94c5ec0f.pack']
# /content/Knee-X-ray/.git/objects/info -> Files: []
# /content/Knee-X-ray/.git/refs -> Files: []
# /content/Knee-X-ray/.git/refs/remotes -> Files: []
# /content/Knee-X-ray/.git/refs/remotes/origin -> Files: ['HEAD']
# /content/Knee-X-ray/.git/refs/tags -> Files: []
# ...

# %%
# !apt-get install unrar
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
# ساخت پوشه برای خروجی‌ها
# !mkdir /content/Knee-X-ray/train
# !mkdir /content/Knee-X-ray/val
# !mkdir /content/Knee-X-ray/test

# ✅ استخراج از مسیر درست
# !unrar x /content/Knee-X-ray/train.rar /content/Knee-X-ray/train/
# !unrar x /content/Knee-X-ray/val.rar /content/Knee-X-ray/val/
# !unrar x /content/Knee-X-ray/test.rar /content/Knee-X-ray/test/
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
import os

def count_images_by_class(data_dir):
    for split in ['train', 'val', 'test']:
        print(f'\n🔹 {split.upper()} split:')
        split_path = os.path.join(data_dir, split)
        for cls in os.listdir(split_path):
            cls_path = os.path.join(split_path, cls)
            count = len(os.listdir(cls_path))
            print(f'  {cls}: {count} images')

count_images_by_class('/content/Knee-X-ray')
# Out:
# 🔹 TRAIN split:
#   train: 2 images
#
# 🔹 VAL split:
#   val: 2 images
#
# 🔹 TEST split:
#   test: 2 images

# %%
import os

for root, dirs, files in os.walk('/content/Knee-X-ray/train'):
    print(f'{root} -> {len(files)} files')
# Out:
# /content/Knee-X-ray/train -> 0 files
# /content/Knee-X-ray/train/train -> 0 files
# /content/Knee-X-ray/train/train/AbNormal -> 2520 files
# /content/Knee-X-ray/train/train/Normal -> 1260 files

# %%
import os

def count_images_by_class_fixed(data_dir):
    for split in ['train/train', 'val/val', 'test/test']:
        print(f'\n🔹 {split.upper()} split:')
        split_path = os.path.join(data_dir, split)
        for cls in os.listdir(split_path):
            cls_path = os.path.join(split_path, cls)
            count = len(os.listdir(cls_path))
            print(f'  {cls}: {count} images')

count_images_by_class_fixed('/content/Knee-X-ray')
# Out:
# 🔹 TRAIN/TRAIN split:
#   AbNormal: 2520 images
#   Normal: 1260 images
#
# 🔹 VAL/VAL split:
#   AbNormal: 720 images
#   Normal: 360 images
#
# 🔹 TEST/TEST split:
#   AbNormal: 360 images
#   Normal: 180 images

# %%
import matplotlib.pyplot as plt
import numpy as np

# داده‌های شمارش‌شده
splits = ['Train', 'Val', 'Test']
normal_counts = [1260, 360, 180]
abnormal_counts = [2520, 720, 360]

x = np.arange(len(splits))  # موقعیت روی محور x
width = 0.35  # عرض میله‌ها

# رسم نمودار
plt.figure(figsize=(8, 5))
bars1 = plt.bar(x - width/2, normal_counts, width, label='Normal', color='green')
bars2 = plt.bar(x + width/2, abnormal_counts, width, label='AbNormal', color='red')

# تنظیمات نمودار
plt.xlabel('Dataset Split')
plt.ylabel('Number of Images')
plt.title('Class Distribution in Train, Val, and Test Sets')
plt.xticks(x, splits)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)

# نمایش مقادیر روی میله‌ها
for bar in bars1 + bars2:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 30, f'{yval}', ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %%
from torchvision import transforms

preprocessing = transforms.Compose([
    transforms.Grayscale(),                      # فقط کانال خاکستری
    transforms.Resize((224, 224)),              # نرمال‌سازی اندازه تصاویر
    transforms.GaussianBlur(3, sigma=(0.1, 1.0)), # حذف نویز (Gaussian)
    transforms.ToTensor(),                      # تبدیل به Tensor
    transforms.Normalize([0.5], [0.5])          # نرمال‌سازی intensity به [-1,1]
])

# %%
train_augmented_transforms = transforms.Compose([
    transforms.Grayscale(),
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),               # آینه‌ای
    transforms.RandomRotation(10),                   # چرخش ±۱۰ درجه
    transforms.RandomAffine(degrees=5, translate=(0.05, 0.05)),  # شیفت جزئی
    transforms.GaussianBlur(3, sigma=(0.1, 1.0)),     # حذف نویز
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

# %% [markdown]
# وظایف:
#
# ۱) تحلیل مقدماتی داده‌ها
#
# ۲) پیش‌پردازش و افزایش داده : یک خط لوله پیش‌پردازش برای مدیریت نویز و تغییرات در تصاویر اشعه ایکس (مانند نرمال‌سازی، حذف نویز) توصیف کنید.هدف خط لوله پیش‌پردازش
#
# کاهش اثرات نویز و تغییرات روشنایی و کنتراست در تصاویر اشعه ایکس
#
# یکنواخت‌سازی داده‌ها برای یادگیری بهتر مدل‌های یادگیری عمیق
#
# حفظ ویژگی‌های مهم پزشکی تصویر (مثل ساختار استخوان)
#
# مراحل خط لوله: تغییر اندازه حذف نویز نرمال‌سازی شدت پیکسل تبدیل به خاکستری
#
# برای حداقل یک تکنیک پیش‌پردازش (مانند نرمال‌سازی یا فیلتر کردن) توجیه ریاضی ارائه دهید.
#
# حداقل سه تکنیک افزایش داده مناسب برای تصاویر اشعه ایکس پیشنهاد دهید تا اندازه مؤثر مجموعه آموزشی افزایش یابد. توضیح دهید چرا هر تکنیک برای این وظیفه پزشکی مناسب است. آینه‌ای کردن تصاویر:در تصاویر واقعی اشعه ایکس، زاویه تصویربرداری ممکن است کمی متفاوت باشد.
#
# این کمک می‌کند مدل نسبت به زاویه‌های جزئی مقاوم شود و در تشخیص صحیح بهتر عمل کند. چرخش تصادفی:در تصاویر واقعی اشعه ایکس، زاویه تصویربرداری ممکن است کمی متفاوت باشد.
#
# این کمک می‌کند مدل نسبت به زاویه‌های جزئی مقاوم شود و در تشخیص صحیح بهتر عمل کند. شیفت و تغییر اندازه کوچک :در زمان گرفتن تصویر، ممکن است موقعیت دقیق زانو کمی جابه‌جا یا نزدیک‌تر/دورتر باشد.
#
# این افزایش داده باعث می‌شود مدل نسبت به موقعیت‌های کمی متفاوت تصویر مقاوم شود.

# %%
# !pip install torchvision scikit-learn

import torch
import torchvision.transforms as transforms
from torchvision.models import resnet50
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 101.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
class KneeXrayDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.images = []
        self.labels = []

        classes = {'Normal': 0, 'AbNormal': 1}

        for cls in classes:
            cls_path = os.path.join(root_dir, cls)
            for img_name in os.listdir(cls_path):
                self.images.append(os.path.join(cls_path, img_name))
                self.labels.append(classes[cls])

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        image = Image.open(img_path).convert('RGB')  # تبدیل به RGB چون مدل ResNet نیاز داره
        if self.transform:
            image = self.transform(image)
        label = self.labels[idx]
        return image, label

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],  # مقادیر mean/std پیش‌فرض ImageNet
                         std=[0.229, 0.224, 0.225]),
])

# %%
train_dataset = KneeXrayDataset('/content/Knee-X-ray/train/train', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)

test_dataset = KneeXrayDataset('/content/Knee-X-ray/val/val', transform=transform)  # فرض val داده تست ماست
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model_resnet = resnet50(pretrained=True)
model_resnet = model_resnet.to(device)
model_resnet.eval()

# حذف لایه FC آخر
feature_extractor = torch.nn.Sequential(*list(model_resnet.children())[:-1])
feature_extractor = feature_extractor.to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 118MB/s]

# %%
def extract_features(data_loader):
    features = []
    labels = []
    with torch.no_grad():
        for imgs, lbls in data_loader:
            imgs = imgs.to(device)
            output = feature_extractor(imgs)  # خروجی ابعاد: batch_size x 2048 x 1 x 1
            output = output.view(output.size(0), -1)  # تبدیل به batch_size x 2048
            features.append(output.cpu().numpy())
            labels.append(lbls.numpy())
    features = np.concatenate(features, axis=0)
    labels = np.concatenate(labels, axis=0)
    return features, labels

# %%
def extract_features(data_loader):
    features = []
    labels = []
    with torch.no_grad():
        for imgs, lbls in data_loader:
            imgs = imgs.to(device)
            output = feature_extractor(imgs)  # خروجی ابعاد: batch_size x 2048 x 1 x 1
            output = output.view(output.size(0), -1)  # تبدیل به batch_size x 2048
            features.append(output.cpu().numpy())
            labels.append(lbls.numpy())
    features = np.concatenate(features, axis=0)
    labels = np.concatenate(labels, axis=0)
    return features, labels

# %%
from torchvision import transforms
from torch.utils.data import Dataset
from PIL import Image
import os

class KneeXrayDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = []
        self.labels = []

        for label, class_name in enumerate(['Normal', 'AbNormal']):
            class_dir = os.path.join(root_dir, class_name)
            for img_name in os.listdir(class_dir):
                self.image_paths.append(os.path.join(class_dir, img_name))
                self.labels.append(label)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = Image.open(img_path).convert("L")  # grayscale
        if self.transform:
            image = self.transform(image)
        return image, self.labels[idx]

# %%
from torchvision import models
import torch
import numpy as np
from torch.utils.data import DataLoader

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

extract_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

# %%
train_dataset = KneeXrayDataset('/content/Knee-X-ray/train/train', transform=extract_transform)
test_dataset = KneeXrayDataset('/content/Knee-X-ray/test/test', transform=extract_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
resnet = models.resnet18(pretrained=True)
feature_extractor = torch.nn.Sequential(*list(resnet.children())[:-1])  # حذف لایه نهایی
feature_extractor = feature_extractor.to(device)
feature_extractor.eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 197MB/s]
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# ...

# %%
def extract_features(data_loader):
    features = []
    labels = []
    with torch.no_grad():
        for imgs, lbls in data_loader:
            imgs = imgs.to(device)

# %%
# فرض: train_dataset و test_dataset از قبل ساخته شده‌ن
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
def extract_features(data_loader):
    features = []
    labels = []
    with torch.no_grad():
        for imgs, lbls in data_loader:
            imgs = imgs.to(device)
            output = feature_extractor(imgs)
            output = output.view(output.size(0), -1)
            features.append(output.cpu().numpy())
            labels.append(lbls.numpy())
    features = np.concatenate(features, axis=0)
    labels = np.concatenate(labels, axis=0)
    return features, labels

# %%
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import os

class KneeXrayDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.samples = []
        for label, class_name in enumerate(['Normal', 'AbNormal']):
            class_dir = os.path.join(root_dir, class_name)
            for fname in os.listdir(class_dir):
                self.samples.append((os.path.join(class_dir, fname), label))
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        return image, label

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
train_dataset = KneeXrayDataset('/content/Knee-X-ray/train/train', transform=transform)
test_dataset = KneeXrayDataset('/content/Knee-X-ray/test/test', transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
import torch
from torchvision import models
import torch.nn as nn
import numpy as np

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
resnet = models.resnet18(pretrained=True)
feature_extractor = nn.Sequential(*list(resnet.children())[:-1]).to(device)
feature_extractor.eval()

def extract_features(data_loader):
    features, labels = [], []
    with torch.no_grad():
        for x, y in data_loader:
            x = x.to(device)
            out = feature_extractor(x)
            out = out.view(out.size(0), -1)
            features.append(out.cpu().numpy())
            labels.append(y.numpy())
    return np.concatenate(features), np.concatenate(labels)

X_train, y_train = extract_features(train_loader)
X_test, y_test = extract_features(test_loader)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report

rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train, y_train)
rf_preds = rf.predict(X_test)
print("🎯 Random Forest:\n", classification_report(y_test, rf_preds))

svm = SVC(kernel='linear')
svm.fit(X_train, y_train)
svm_preds = svm.predict(X_test)
print("🎯 SVM:\n", classification_report(y_test, svm_preds))
# Out:
# 🎯 Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74       180
#            1       0.85      0.91      0.88       360
#
#     accuracy                           0.84       540
#    macro avg       0.83      0.80      0.81       540
# weighted avg       0.84      0.84      0.84       540
#
# 🎯 SVM:
#                precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67       180
#            1       0.83      0.84      0.83       360
#
#     accuracy                           0.78       540
#    macro avg       0.75      0.75      0.75       540
# weighted avg       0.78      0.78      0.78       540

# %%
import torch.nn.functional as F

class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 56 * 56, 100),
            nn.ReLU(),
            nn.Linear(100, 2)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

model = SimpleCNN().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# %%
def train_model(model, loader, optimizer, criterion):
    model.train()
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        out = model(x)
        loss = criterion(out, y)
        loss.backward()
        optimizer.step()

def evaluate_model(model, loader):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device)
            out = model(x)
            preds = out.argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(y.numpy())
    return classification_report(all_labels, all_preds)

# آموزش ۵ دوره
for epoch in range(5):
    train_model(model, train_loader, optimizer, criterion)
    print(f"Epoch {epoch+1} done.")

print("🎯 CNN Evaluation:\n", evaluate_model(model, test_loader))
# Out:
# Epoch 1 done.
# Epoch 2 done.
# Epoch 3 done.
# Epoch 4 done.
# Epoch 5 done.
# 🎯 CNN Evaluation:
#                precision    recall  f1-score   support
#
#            0       0.69      0.73      0.71       180
#            1       0.86      0.84      0.85       360
#
#     accuracy                           0.80       540
#    macro avg       0.77      0.78      0.78       540
# weighted avg       0.80      0.80      0.80       540

# %%
from torchvision import models
import torch.nn as nn

resnet_transfer = models.resnet18(pretrained=True)

# Freeze همه‌ی لایه‌ها به جز Fully Connected
for param in resnet_transfer.parameters():
    param.requires_grad = False

# تغییر خروجی به ۲ کلاس (Normal / AbNormal)
num_ftrs = resnet_transfer.fc.in_features
resnet_transfer.fc = nn.Linear(num_ftrs, 2)

resnet_transfer = resnet_transfer.to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(resnet_transfer.fc.parameters(), lr=0.001)

# %%
def train_model(model, loader, optimizer, criterion):
    model.train()
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        out = model(x)
        loss = criterion(out, y)
        loss.backward()
        optimizer.step()

def evaluate_model(model, loader):
    model.eval()
    preds, trues = [], []
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device)
            out = model(x)
            pred = out.argmax(dim=1).cpu().numpy()
            preds.extend(pred)
            trues.extend(y.numpy())
    return classification_report(trues, preds)

# آموزش در 5 دوره
for epoch in range(5):
    train_model(resnet_transfer, train_loader, optimizer, criterion)
    print(f"✅ Epoch {epoch+1} done.")

# ارزیابی
from sklearn.metrics import classification_report
print("🎯 Transfer Learning Evaluation:\n", evaluate_model(resnet_transfer, test_loader))
# Out:
# ✅ Epoch 1 done.
# ✅ Epoch 2 done.
# ✅ Epoch 3 done.
# ✅ Epoch 4 done.
# ✅ Epoch 5 done.
# 🎯 Transfer Learning Evaluation:
#                precision    recall  f1-score   support
#
#            0       0.75      0.51      0.61       180
#            1       0.79      0.91      0.85       360
#
#     accuracy                           0.78       540
#    macro avg       0.77      0.71      0.73       540
# weighted avg       0.78      0.78      0.77       540

# %%
import pandas as pd

# نام مدل‌ها
models = ['ML Model 1', 'ML Model 2', 'CNN', 'Transfer Learning']

# نتایج فرضی هر مدل (اینها رو با نتایج واقعی‌ات جایگزین کن)
results = {
    'ML Model 1': {'Precision': 0.75, 'Recall': 0.70, 'Accuracy': 0.72, 'F1-score': 0.72},
    'ML Model 2': {'Precision': 0.78, 'Recall': 0.73, 'Accuracy': 0.75, 'F1-score': 0.75},
    'CNN':       {'Precision': 0.85, 'Recall': 0.80, 'Accuracy': 0.83, 'F1-score': 0.82},
    'Transfer Learning': {'Precision': 0.90, 'Recall': 0.88, 'Accuracy': 0.89, 'F1-score': 0.89}
}

# ساخت لیست دیکشنری‌ها
rows = []
for model in models:
    row = {
        'Model': model,
        'Precision': results[model]['Precision'],
        'Recall': results[model]['Recall'],
        'Accuracy': results[model]['Accuracy'],
        'F1-score': results[model]['F1-score']
    }
    rows.append(row)

# ساخت DataFrame
df = pd.DataFrame(rows)

print(df)
# Out:
#                Model  Precision  Recall  Accuracy  F1-score
# 0         ML Model 1       0.75    0.70      0.72      0.72
# 1         ML Model 2       0.78    0.73      0.75      0.75
# 2                CNN       0.85    0.80      0.83      0.82
# 3  Transfer Learning       0.90    0.88      0.89      0.89
